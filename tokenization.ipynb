# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# Fix: download all required resources
nltk.download('punkt')
nltk.download('punkt_tab')   # important fix
nltk.download('stopwords')

text = """NLTK is a powerful library for natural language processing.
It helps in tasks like tokenization, stopword removal, and stemming.
This program demonstrates all of them together."""

# Sentence Tokenization
sentences = sent_tokenize(text)
print("Sentences:")
print(sentences)

# Word Tokenization
words = word_tokenize(text)
print("\nWords:")
print(words)

# Stopword Removal
stop_words = set(stopwords.words('english'))
filtered_words = [w for w in words if w.lower() not in stop_words]

print("\nAfter Stopword Removal:")
print(filtered_words)

# Stemming
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(w) for w in filtered_words]

print("\nAfter Stemming:")
print(stemmed_words)

#The program uses NLTK to preprocess text by tokenizing it into sentences and words, removing stopwords, and applying stemming to obtain root words for efficient text analysis.
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Sentences:
# ['NLTK is a powerful library for natural language processing.', 'It helps in tasks like tokenization, stopword removal, and stemming.', 'This program demonstrates all of them together.']
#
# Words:
# ['NLTK', 'is', 'a', 'powerful', 'library', 'for', 'natural', 'language', 'processing', '.', 'It', 'helps', 'in', 'tasks', 'like', 'tokenization', ',', 'stopword', 'removal', ',', 'and', 'stemming', '.', 'This', 'program', 'demonstrates', 'all', 'of', 'them', 'together', '.']
#
# After Stopword Removal:
# ['NLTK', 'powerful', 'library', 'natural', 'language', 'processing', '.', 'helps', 'tasks', 'like', 'tokenization', ',', 'stopword', 'removal', ',', 'stemming', '.', 'program', 'demonstrates', 'together', '.']
#
# After Stemming:
# ...
