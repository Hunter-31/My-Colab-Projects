# %% [markdown]
# <a href="https://colab.research.google.com/github/Hunter-31/My-Colab-Projects/blob/main/Word2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

sentences = [
    ["the","dog","barks"],
    ["the","cat","meows"],
    ["dog","and","cat","are","pets"],
    ["the","dog","chases","the","cat"],
    ["pets","are","friendly"]
]

model = Word2Vec(sentences, vector_size=50, window=3, min_count=1, sg=1)

words = list(model.wv.index_to_key)
vectors = [model.wv[w] for w in words]

# PCA
pca = PCA(n_components=2)
coords = pca.fit_transform(vectors)

# Plot
plt.figure(figsize=(8,6))

for i, word in enumerate(words):
    x, y = coords[i]
    plt.scatter(x, y)

    # offset label to avoid overlap
    plt.annotate(word, (x, y), xytext=(5, 5), textcoords='offset points')

plt.title("Word2Vec Embeddings (Clean Visualization)")
plt.grid()
plt.show()
