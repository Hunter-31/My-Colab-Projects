# %% [markdown]
# <a href="https://colab.research.google.com/github/Hunter-31/My-Colab-Projects/blob/main/stem_lemma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import wordnet

# --- Required downloads ---
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')

# -------------------------------
# Input text
# -------------------------------
text = "The striped bats are hanging on their feet and ate best fishes"

# -------------------------------
# Tokenization
# -------------------------------
words = word_tokenize(text)
print("Original Words:")
print(words)

# -------------------------------
# 1. Stemming
# -------------------------------
stemmer = PorterStemmer()
stemmed = [stemmer.stem(word) for word in words]

print("\nStemmed Words:")
print(stemmed)

# -------------------------------
# 2. Lemmatization
# -------------------------------
lemmatizer = WordNetLemmatizer()

# (Simple lemmatization without POS)
lemmatized = [lemmatizer.lemmatize(word) for word in words]

print("\nLemmatized Words (without POS):")
print(lemmatized)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Original Words:
# ['The', 'striped', 'bats', 'are', 'hanging', 'on', 'their', 'feet', 'and', 'ate', 'best', 'fishes']
#
# Stemmed Words:
# ['the', 'stripe', 'bat', 'are', 'hang', 'on', 'their', 'feet', 'and', 'ate', 'best', 'fish']
#
# Lemmatized Words (without POS):
# ['The', 'striped', 'bat', 'are', 'hanging', 'on', 'their', 'foot', 'and', 'ate', 'best', 'fish']
