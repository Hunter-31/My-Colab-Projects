# %% [markdown]
# <a href="https://colab.research.google.com/github/Hunter-31/My-Colab-Projects/blob/main/cfg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk import CFG
from nltk.parse import ChartParser

# -------------------------------
# 1. Define Context-Free Grammar
# -------------------------------
grammar = CFG.fromstring("""
S  -> NP VP
NP -> Det N | Det Adj N | 'John' | 'Mary'
VP -> V NP | V
Det -> 'a' | 'the'
Adj -> 'big' | 'small'
N -> 'cat' | 'dog'
V -> 'sees' | 'likes'
""")

# -------------------------------
# 2. Create Parser
# -------------------------------
parser = ChartParser(grammar)

# -------------------------------
# 3. Input Sentence
# -------------------------------
sentence = "the big dog sees a cat"
tokens = sentence.split()

print("Sentence:", sentence)

# -------------------------------
# 4. Parse Sentence
# -------------------------------
print("\nParse Trees:")
for tree in parser.parse(tokens):
    print(tree)
# Out:
# Sentence: the big dog sees a cat
#
# Parse Trees:
# (S
#   (NP (Det the) (Adj big) (N dog))
#   (VP (V sees) (NP (Det a) (N cat))))
